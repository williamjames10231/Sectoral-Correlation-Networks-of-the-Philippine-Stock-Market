# %%
from itertools import combinations

# %%
'''
This is the base Complete Graph
'''
# Out:
# '\nThis is the base Complete Graph\n'

# %%
sectors = ["Property", "Mining & Oil", "Financials", "Holding Firms", "Industrial", "Services"]
K6 = Graph()
K6.add_vertices(sectors)
K6.add_edges(combinations(sectors, 2))

for u, v, _ in K6.edges():
    K6.set_edge_label(u,v, "{:.2f}".format(0.00))

K6.show(figsize=8, edge_labels=True, layout='circular')
K6.plot(figsize=8, edge_labels=True, layout='circular').save("CompleteGraph.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 sectors = ["Property", "Mining & Oil", "Financials", "Holding Firms", "Industrial", "Services"]
# ----> 2 K6 = Graph()
#       3 K6.add_vertices(sectors)
#       4 K6.add_edges(combinations(sectors, 2))
#
# NameError: name 'Graph' is not defined

# %%
'''
This is the batch a Corrtelations Complete Graph
'''

# %%
corr_matrix_batch_a = matrix(RDF,6,6,[
    1.0,0.289601069375887,0.40029070661885,0.427268116077047,0.447992040176785,0.206448774284328,
    0.289601069375887,1.0,0.383701299301501,0.360936518803715,0.22685593861087,0.0610828771384814,
    0.40029070661885,0.383701299301501,1.0,0.353455367041583,0.238850450180399,0.323369989142289,
    0.427268116077047,0.360936518803715,0.353455367041583,1.0,0.700198246202028,0.492793861781693,
    0.447992040176785,0.22685593861087,0.238850450180399,0.700198246202028,1.0,0.51545110582067,
    0.206448774284328,0.0610828771384814,0.323369989142289,0.492793861781693,0.51545110582067,1.0
])
K6_batch_a_corr = Graph(corr_matrix_batch_a, format="adjacency_matrix", vertex_labels=sectors)
K6_batch_a_corr.remove_loops()
mapping_a = {i: sectors[i] for i in range(6)}
K6_batch_a_corr.relabel(mapping_a)
K6_batch_a_corr.show(figsize=8, edge_labels=True, layout='circular')
K6_batch_a_corr.plot(figsize=8, edge_labels=True, layout='circular').save("CompleteGraph_batch_a_corr.png")

# %%
'''
This is the batch b Corrtelations Complete Graph
'''

# %%
corr_matrix_batch_b = matrix(RDF,6,6,[
    1.0,0.868429764365171,0.843601006009597,0.919989678576377,0.807056937683122,0.873163425660659,
    0.868429764365171,1.0,0.792531453124565,0.834165037135453,0.812976253369536,0.876838376569595,
    0.843601006009597,0.792531453124565,1.0,0.898150007826343,0.79194769817724,0.837812766160291,
    0.919989678576377,0.834165037135453,0.898150007826343,1.0,0.829582443189127,0.893511582460855,
    0.807056937683122,0.812976253369536,0.79194769817724,0.829582443189127,1.0,0.810939033774568,
    0.873163425660659,0.876838376569595,0.837812766160291,0.893511582460855,0.810939033774568,1.0
])
K6_batch_b_corr = Graph(corr_matrix_batch_b, format="adjacency_matrix", vertex_labels=sectors)
K6_batch_b_corr.remove_loops()
mapping_b = {i: sectors[i] for i in range(6)}
K6_batch_b_corr.relabel(mapping_b)
K6_batch_b_corr.show(figsize=8, edge_labels=True, layout='circular')
K6_batch_b_corr.plot(figsize=8, edge_labels=True, layout='circular').save("CompleteGraph_batch_b_corr.png")

# %%
'''
This is the batch a Distance Complete Graph
'''

# %%
dist_matrix_batch_a = matrix(RDF,6,6,[
    0.0,1.19197225691214,1.09517970523668,1.07026341049571,1.05072161853006,1.25980254462013,
    1.19197225691214,0.0,1.11022403207506,1.13054277335825,1.2434983404807,1.37034092317315,
    1.09517970523668,1.11022403207506,0.0,1.13714082941245,1.23381485630511,1.16329704792689,
    1.07026341049571,1.13054277335825,1.13714082941245,0.0,0.774340692199464,1.00718035943748,
    1.05072161853006,1.2434983404807,1.23381485630511,0.774340692199464,0.0,0.984427645060143,
    1.25980254462013,1.37034092317315,1.16329704792689,1.00718035943748,0.984427645060143,0.0
])
K6_batch_a_dist = Graph(dist_matrix_batch_a, format="adjacency_matrix", vertex_labels=sectors)
K6_batch_a_dist.remove_loops()
mapping_a_dist = {i: sectors[i] for i in range(6)}
K6_batch_a_dist.relabel(mapping_a_dist)
K6_batch_a_dist.show(figsize=8, edge_labels=True, layout='circular')
K6_batch_a_dist.plot(figsize=8, edge_labels=True, layout='circular').save("CompleteGraph_batch_a_dist.png")

# %%
'''
This is the batch b Distance Complete Graph
'''

# %%
dist_matrix_batch_b = matrix(RDF,6,6,[
    0.0,0.51297219346633,0.559283459420003,0.400025802726831,0.621197331476687,0.503659754872952,
    0.51297219346633,0.0,0.644156109767555,0.575907914278918,0.611594222717096,0.496309628015426,
    0.559283459420003,0.644156109767555,0.0,0.4513313465153,0.645061705300756,0.569538820168931,
    0.400025802726831,0.575907914278918,0.4513313465153,0.0,0.583810854319913,0.461494133308636,
    0.621197331476687,0.611594222717096,0.645061705300756,0.583810854319913,0.0,0.614916199535242,
    0.503659754872952,0.496309628015426,0.569538820168931,0.461494133308636,0.614916199535242,0.0
])
K6_batch_b_dist = Graph(dist_matrix_batch_b, format="adjacency_matrix", vertex_labels=sectors)
K6_batch_b_dist.remove_loops()
mapping_b_dist = {i: sectors[i] for i in range(6)}
K6_batch_b_dist.relabel(mapping_b_dist)
K6_batch_b_dist.show(figsize=8, edge_labels=True, layout='circular')
K6_batch_b_dist.plot(figsize=8, edge_labels=True, layout='circular').save("CompleteGraph_batch_b_dist.png")

# %%
'''
This is the batch a distance MST via Kruskal's Algortihm
'''

# %%
K6_batch_a_dist_copy = K6_batch_a_dist
K6_batch_a_dist_copy_mst_edges = K6_batch_a_dist_copy.min_spanning_tree(algorithm="Kruskal")
K6_batch_a_dist_mst = Graph(K6_batch_a_dist_copy_mst_edges,weighted=True)
K6_batch_a_dist_mst.show(figsize=8, edge_labels=True, layout='spring', edge_color='red')
K6_batch_a_dist_mst.plot(figsize=8, edge_labels=True, layout='spring').save("CompleteGraph_batch_a_dist_mst.png")

# %%
'''
This is the batch b distance MST via Kruskal's Algortihm
'''

# %%
K6_batch_b_dist_copy = K6_batch_b_dist
K6_batch_b_dist_copy_mst_edges = K6_batch_b_dist_copy.min_spanning_tree(algorithm="Kruskal")
K6_batch_b_dist_mst = Graph(K6_batch_b_dist_copy_mst_edges,weighted=True)
K6_batch_b_dist_mst.show(figsize=8, edge_labels=True, layout='spring', edge_color='red')
K6_batch_b_dist_mst.plot(figsize=8, edge_labels=True, layout='spring').save("CompleteGraph_batch_b_dist_mst.png")
